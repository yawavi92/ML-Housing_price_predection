# %%
import pandas as pd
import os

# %%
melbourne_df = pd.read_csv('Melbourne_housing_FULL.csv')
melbourne_df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
melbourne_df.shape
# Out:
# (34857, 21)

# %%
melbourne_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
clean_melbourne_df = melbourne_df[["Suburb",
                                   "Address",
                                   "Rooms",
                                   "Type",
                                   "Price",
                                   "Date",
                                   "Distance",
                                   "Postcode",
                                   "Bedroom2",
                                   "Bathroom",
                                   "Car",
                                   "Landsize",
                                   "CouncilArea",
                                   "Lattitude",
                                   "Longtitude",
                                   "Propertycount"]]

# %%
clean_melbourne_df.head()
# Out:
#        Suburb             Address  Rooms Type      Price       Date  Distance  \
# 0  Abbotsford       68 Studley St      2    h        NaN  3/09/2016       2.5
# 1  Abbotsford        85 Turner St      2    h  1480000.0  3/12/2016       2.5
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0  4/02/2016       2.5
# 3  Abbotsford  18/659 Victoria St      3    u        NaN  4/02/2016       2.5
# 4  Abbotsford        5 Charles St      3    h  1465000.0  4/03/2017       2.5
#
#    Postcode  Bedroom2  Bathroom  Car  Landsize         CouncilArea  Lattitude  \
# 0    3067.0       2.0       1.0  1.0     126.0  Yarra City Council   -37.8014
# 1    3067.0       2.0       1.0  1.0     202.0  Yarra City Council   -37.7996
# 2    3067.0       2.0       1.0  0.0     156.0  Yarra City Council   -37.8079
# 3    3067.0       3.0       2.0  1.0       0.0  Yarra City Council   -37.8114
# 4    3067.0       3.0       2.0  0.0     134.0  Yarra City Council   -37.8093
#
# ...

# %%
print(len(clean_melbourne_df))
# Out:
# 34857

# %%
clean_melbourne_df.drop(["Price"]), axis
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-b1845448ca3c> in <module>
# ----> 1 clean_melbourne_df.drop(["Price"]), axis
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
clean_melbourne_df = clean_melbourne_df.rename(columns={"Bedroom2": "Bedrooms",
                                                        "Car": "CarSpots",
                                                        "Lattitude": "Latitude",
                                                        "Longtitude": "Longitude"})

# %%
clean_melbourne_df.head()

# %%
clean_melbourne_df.dropna(inplace=True)

# %%
print(len(clean_melbourne_df))

# %%
clean_melbourne_df
